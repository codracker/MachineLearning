# %%
'''
Q1.Clean data and update the CSV file
Replace all column values which contain ‘?’ and n.a with NaN.
Q2. Find the most expensive car company name
Q3. Print All Toyota Cars details
Q4. Count total cars per company
Q5. Find each company’s Higesht price car
Q6. Find the average mileage of each car making company
Q7. Sort all cars by Price column

'''
# Out:
# '\nQ1.Clean data and update the CSV file\nReplace all column values which contain ‘?’ and n.a with NaN.\nQ2. Find the most expensive car company name\nQ3. Print All Toyota Cars details\nQ4. Count total cars per company\nQ5. Find each company’s Higesht price car\nQ6. Find the average mileage of each car making company\nQ7. Sort all cars by Price column\n\n'

# %%
#importing the required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#reading the required dataset
df = pd.read_csv("Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   make               205 non-null    object
#  2   fuel-type          205 non-null    object
#  3   aspiration         205 non-null    object
#  4   num-of-doors       203 non-null    object
#  5   body-style         205 non-null    object
#  6   drive-wheels       205 non-null    object
#  7   engine-location    205 non-null    object
#  8   wheel-base         205 non-null    float64
#  9   length             205 non-null    float64
#  10  width              205 non-null    float64
#  11  height             205 non-null    float64
#  12  curb-weight        205 non-null    int64
#  13  engine-type        205 non-null    object
#  14  num-of-cylinders   205 non-null    object
#  15  engine-size        205 non-null    int64
# ...

# %%
#to check null values
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#dropping column with maximum value
df = df.drop(['normalized-losses'],axis = 1)

# %%
df.dropna(inplace = True)

# %%
#to check null values
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#replacing "?" with "nan"
df = df.replace("?",np.nan)

# %%
df['price'][1]
# Out:
# '16500'

# %%
#Print All Toyota Cars details

all_toyota_cars= df.groupby('make').get_group('toyota')
all_toyota_cars
# Out:
#      symboling    make fuel-type aspiration num-of-doors   body-style  \
# 150          1  toyota       gas        std          two    hatchback
# 151          1  toyota       gas        std          two    hatchback
# 152          1  toyota       gas        std         four    hatchback
# 153          0  toyota       gas        std         four        wagon
# 154          0  toyota       gas        std         four        wagon
# 155          0  toyota       gas        std         four        wagon
# 156          0  toyota       gas        std         four        sedan
# 157          0  toyota       gas        std         four    hatchback
# 158          0  toyota    diesel        std         four        sedan
# 159          0  toyota    diesel        std         four    hatchback
# 160          0  toyota       gas        std         four        sedan
# 161          0  toyota       gas        std         four    hatchback
# ...

# %%
#Count total cars per company
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# mazda            12
# peugot           11
# volvo            11
# mercedes-benz     8
# dodge             8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: make, dtype: int64

# %%
#Find each company’s Higesht price car
#company_highest_price = df.groupby('make')['make','price'].max()
#company_highest_price
#company = df.groupby('make')
#company_highest_price = company['make','price'].max()

# %%
# Find the average mileage of each car making company
import warnings
warnings.filterwarnings("ignore")
avg_mileage_company = df.groupby('make')['make','city-mpg'].mean()
avg_mileage_company
# Out:
#                 city-mpg
# make
# alfa-romero    20.333333
# audi           19.333333
# bmw            19.375000
# chevrolet      41.000000
# dodge          28.500000
# honda          30.384615
# isuzu          24.000000
# jaguar         14.333333
# mazda          27.833333
# mercedes-benz  18.500000
# mercury        19.000000
# mitsubishi     24.923077
# nissan         27.000000
# peugot         22.454545
# plymouth       28.142857
# porsche        17.500000
# saab           20.333333
# subaru         26.333333
# toyota         27.500000
# volkswagen     28.583333
# volvo          21.181818

# %%
#Sort all cars by Price column
df.sort_values(by = 'price')
# Out:
#      symboling        make fuel-type aspiration num-of-doors body-style  \
# 147          0      subaru       gas        std         four      wagon
# 62           0       mazda       gas        std         four      sedan
# 40           0       honda       gas        std         four      sedan
# 42           1       honda       gas        std          two      sedan
# 61           1       mazda       gas        std          two  hatchback
# ..         ...         ...       ...        ...          ...        ...
# 143          0      subaru       gas        std         four      sedan
# 190          3  volkswagen       gas        std          two  hatchback
# 175         -1      toyota       gas        std         four  hatchback
# 169          2      toyota       gas        std          two  hatchback
# 188          2  volkswagen       gas        std         four      sedan
#
#     drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# ...
